# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
ticker = "BCH"

# %%
df = yf.download(ticker)
df = df["2009-01-01":]
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2009-01-02   9.887500   9.896698   9.623833   9.823116   4.851245   29029
# 2009-01-05   9.964147  10.227814   9.902829  10.086783   4.981459   22180
# 2009-01-06  10.368845  11.484829  10.273802  11.484829   5.671898   54470
# 2009-01-07  10.730620  10.883915  10.516008  10.883915   5.375131   59363
# 2009-01-08  10.669302  10.837926  10.470019  10.699961   5.284283   19570
# ...               ...        ...        ...        ...        ...     ...
# 2023-05-26  21.459999  21.469999  21.150000  21.340000  21.340000   84800
# 2023-05-30  21.309999  21.420000  20.900000  21.040001  21.040001   69700
# 2023-05-31  21.070000  21.070000  20.150000  20.200001  20.200001  181600
# 2023-06-01  20.309999  20.920000  20.309999  20.799999  20.799999   68800
# 2023-06-02  21.850000  21.600000  21.170000  21.570000  21.570000   62287
#
# [3629 rows x 6 columns]

# %%
df = df.asfreq('B', method='ffill')

# %%
df.index
# Out:
# DatetimeIndex(['2009-01-02', '2009-01-05', '2009-01-06', '2009-01-07',
#                '2009-01-08', '2009-01-09', '2009-01-12', '2009-01-13',
#                '2009-01-14', '2009-01-15',
#                ...
#                '2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25',
#                '2023-05-26', '2023-05-29', '2023-05-30', '2023-05-31',
#                '2023-06-01', '2023-06-02'],
#               dtype='datetime64[ns]', name='Date', length=3761, freq='B')

# %%
plt.figure(figsize=(12, 8))
plt.plot(df["Adj Close"])
plt.title(f"{ticker} Adjusted Close Price")
plt.xlabel('Year')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df['Adj Close'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic        -2.493600
# p-value                    0.117039
# # lags used                3.000000
# # observations          3757.000000
# critical value (1%)       -3.432092
# critical value (5%)       -2.862310
# critical value (10%)      -2.567180
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
len(df)
# Out:
# 3761

# %%
q_80 = int(len(df) * .8)

# %%
y_train = df['Adj Close'].iloc[:q_80]
y_test = df['Adj Close'].iloc[q_80:]

# %%
y_train.plot(figsize = (12, 8))
y_test.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = auto_arima(y_train, trace = True, seasonal = True, m = 5)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[5] intercept   : AIC=356.182, Time=3.74 sec
#  ARIMA(0,1,0)(0,0,0)[5] intercept   : AIC=380.101, Time=0.30 sec
#  ARIMA(1,1,0)(1,0,0)[5] intercept   : AIC=357.883, Time=0.45 sec
#  ARIMA(0,1,1)(0,0,1)[5] intercept   : AIC=356.960, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[5]             : AIC=378.693, Time=0.28 sec
#  ARIMA(2,1,2)(0,0,1)[5] intercept   : AIC=354.247, Time=2.24 sec
#  ARIMA(2,1,2)(0,0,0)[5] intercept   : AIC=356.315, Time=1.14 sec
#  ARIMA(2,1,2)(0,0,2)[5] intercept   : AIC=356.096, Time=3.42 sec
#  ARIMA(2,1,2)(1,0,0)[5] intercept   : AIC=354.349, Time=1.83 sec
#  ARIMA(2,1,2)(1,0,2)[5] intercept   : AIC=357.069, Time=5.53 sec
#  ARIMA(1,1,2)(0,0,1)[5] intercept   : AIC=355.581, Time=2.14 sec
#  ARIMA(2,1,1)(0,0,1)[5] intercept   : AIC=355.378, Time=1.87 sec
#  ARIMA(3,1,2)(0,0,1)[5] intercept   : AIC=355.559, Time=3.65 sec
#  ARIMA(2,1,3)(0,0,1)[5] intercept   : AIC=354.159, Time=4.89 sec
#  ARIMA(2,1,3)(0,0,0)[5] intercept   : AIC=352.159, Time=2.67 sec
#  ARIMA(2,1,3)(1,0,0)[5] intercept   : AIC=354.240, Time=1.53 sec
#  ARIMA(2,1,3)(1,0,1)[5] intercept   : AIC=356.239, Time=2.33 sec
#  ARIMA(1,1,3)(0,0,0)[5] intercept   : AIC=353.163, Time=1.75 sec
#  ARIMA(3,1,3)(0,0,0)[5] intercept   : AIC=351.899, Time=1.84 sec
#  ARIMA(3,1,3)(1,0,0)[5] intercept   : AIC=352.999, Time=4.15 sec
#  ARIMA(3,1,3)(0,0,1)[5] intercept   : AIC=353.015, Time=4.64 sec
#  ARIMA(3,1,3)(1,0,1)[5] intercept   : AIC=354.983, Time=4.99 sec
#  ARIMA(3,1,2)(0,0,0)[5] intercept   : AIC=353.559, Time=2.89 sec
#  ARIMA(4,1,3)(0,0,0)[5] intercept   : AIC=350.575, Time=3.91 sec
#  ARIMA(4,1,3)(1,0,0)[5] intercept   : AIC=351.630, Time=5.71 sec
#  ARIMA(4,1,3)(0,0,1)[5] intercept   : AIC=352.416, Time=5.70 sec
#  ARIMA(4,1,3)(1,0,1)[5] intercept   : AIC=354.590, Time=6.14 sec
#  ARIMA(4,1,2)(0,0,0)[5] intercept   : AIC=352.574, Time=3.38 sec
#  ARIMA(4,1,4)(0,0,0)[5] intercept   : AIC=355.011, Time=3.72 sec
#  ARIMA(3,1,4)(0,0,0)[5] intercept   : AIC=352.503, Time=3.90 sec
#  ARIMA(4,1,3)(0,0,0)[5]             : AIC=349.350, Time=2.15 sec
#  ARIMA(4,1,3)(1,0,0)[5]             : AIC=349.302, Time=2.86 sec
#  ARIMA(4,1,3)(2,0,0)[5]             : AIC=350.097, Time=3.71 sec
#  ARIMA(4,1,3)(1,0,1)[5]             : AIC=352.256, Time=3.33 sec
#  ARIMA(4,1,3)(0,0,1)[5]             : AIC=349.222, Time=2.83 sec
#  ARIMA(4,1,3)(0,0,2)[5]             : AIC=350.212, Time=3.82 sec
#  ARIMA(4,1,3)(1,0,2)[5]             : AIC=351.434, Time=4.33 sec
#  ARIMA(3,1,3)(0,0,1)[5]             : AIC=351.474, Time=2.42 sec
#  ARIMA(4,1,2)(0,0,1)[5]             : AIC=356.425, Time=1.22 sec
#  ARIMA(4,1,4)(0,0,1)[5]             : AIC=355.480, Time=2.85 sec
#  ARIMA(3,1,2)(0,0,1)[5]             : AIC=354.317, Time=1.97 sec
#  ARIMA(3,1,4)(0,0,1)[5]             : AIC=353.078, Time=2.83 sec
#
# Best model:  ARIMA(4,1,3)(0,0,1)[5]
# Total fit time: 125.564 seconds

# %% [markdown]
# Potential models are:
# - SARIMA(4,1,3)x(0,0,1,5)
# - SARIMA(4,1,3)x(2,0,0,5)
# - SARIMA(4,1,3)x(0,0,2,5)
# - SARIMA(4,1,3)x(0,0,0,5) with intercept

# %%
model_list = {"order": [(4, 1, 3), (4, 1, 3), (4, 1 ,3), (4, 1 ,3)], "seasonal_order": [(0,0,0,5), (2,0,0,5), (0,0,2,5), (0,0,0,5)], "trend": ["n", "n", "n", "c"]}

# %%
from statsmodels.tools.eval_measures import rmse

# %%
metrics = pd.DataFrame(data = {"Order" : [], "Seasonal Order": [], "Trend": [], "AIC": [], "BIC" : [], "RMSE": []})
metric_rows = []
   
start = len(y_train)
end = len(y_train) + len(y_test) -1

for order, seasonal_order, trend in zip(model_list["order"], model_list["seasonal_order"], model_list["trend"]):
    model= SARIMAX(y_train, order = order, seasonal_order = seasonal_order, enforce_invertibility = True, trend = trend).fit()

    y_pred = model.predict(start, end)
    rmse_model = rmse(y_test, y_pred)
    
    metric_rows.append({"Order" : order, "Seasonal Order": seasonal_order, "Trend": trend, "AIC": model.aic, "BIC" : model.bic, "RMSE": rmse_model})
    
metrics = pd.concat([metrics, pd.DataFrame(metric_rows)], ignore_index=True)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
metrics = metrics.sort_values("RMSE")
metrics
# Out:
#        Order Seasonal Order Trend         AIC         BIC      RMSE
# 3  (4, 1, 3)   (0, 0, 0, 5)     c  350.575083  404.653366  1.800021
# 0  (4, 1, 3)   (0, 0, 0, 5)     n  349.349821  397.419406  2.468449
# 2  (4, 1, 3)   (0, 0, 2, 5)     n  350.211519  410.298500  2.488658
# 1  (4, 1, 3)   (2, 0, 0, 5)     n  350.097378  410.184360  2.489238

# %% [markdown]
# The best model is SARIMA(0,1,3)x(2,0,2,12)

# %%
selected_model = SARIMAX(y_train, order = metrics["Order"].iloc[0], seasonal_order = metrics["Seasonal Order"].iloc[0], enforce_invertibility = True, trend = metrics["Trend"].iloc[0]).fit()
y_hat_test = selected_model.predict(start, end).rename("Test Predictions")
plt.figure(figsize = (12, 8))
y_test.plot(legend = True)
y_hat_test.plot(legend = True)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <AxesSubplot:xlabel='Date'>

# %%
final_model =  SARIMAX(df["Adj Close"], order = metrics["Order"].iloc[0], seasonal_order = metrics["Seasonal Order"].iloc[0], enforce_invertibility = True, trend = metrics["Trend"].iloc[0]).fit()
final_model.summary()
# Out:
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Adj Close   No. Observations:                 3761
# Model:               SARIMAX(4, 1, 3)   Log Likelihood                -478.010
# Date:                Fri, 02 Jun 2023   AIC                            974.020
# Time:                        15:24:29   BIC                           1030.109
# Sample:                    01-02-2009   HQIC                           993.965
#                          - 06-02-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0041      0.004      0.953      0.341      -0.004       0.012
# ar.L1         -0.0581      0.143     -0.408      0.683      -0.338       0.221
# ar.L2         -0.4608      0.107     -4.302      0.000      -0.671      -0.251
# ar.L3          0.5954      0.143      4.166      0.000       0.315       0.876
# ar.L4         -0.0016      0.018     -0.088      0.930      -0.037       0.034
# ma.L1          0.0151      0.141      0.107      0.915      -0.262       0.292
# ma.L2          0.4372      0.095      4.604      0.000       0.251       0.623
# ma.L3         -0.6584      0.133     -4.937      0.000      -0.920      -0.397
# sigma2         0.0755      0.001     88.742      0.000       0.074       0.077
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              8602.17
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.56   Skew:                             0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
forecast_size = 44

# %%
final_order  = metrics["Order"].iloc[0]
final_seasonal_order = metrics["Seasonal Order"].iloc[0]

# %%
y_forecast = final_model.predict(start = len(df), end = len(df) + forecast_size - 1, typ = "levels").rename(f"SARIMA{final_order}x{final_seasonal_order} Forecast")

# %%
plt.figure(figsize = (12, 8))
df["Adj Close"].plot(legend = True)
y_forecast.plot(legend = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize = (12, 8))
df["Adj Close"].iloc[-30:].plot(legend = True)
y_forecast.plot(legend = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
y_forecast
# Out:
# 2023-06-05    21.558973
# 2023-06-06    21.527741
# 2023-06-07    21.512206
# 2023-06-08    21.523767
# 2023-06-09    21.515732
# 2023-06-12    21.505730
# 2023-06-13    21.520979
# 2023-06-14    21.523957
# 2023-06-15    21.514873
# 2023-06-16    21.527181
# 2023-06-19    21.536457
# 2023-06-20    21.528891
# 2023-06-21    21.536457
# 2023-06-22    21.549064
# 2023-06-23    21.544383
# 2023-06-26    21.547420
# 2023-06-27    21.560952
# 2023-06-28    21.560017
# 2023-06-29    21.559709
# 2023-06-30    21.572268
# 2023-07-03    21.575159
# 2023-07-04    21.573080
# 2023-07-05    21.583404
# 2023-07-06    21.589520
# 2023-07-07    21.587223
# 2023-07-10    21.594746
# 2023-07-11    21.603050
# 2023-07-12    21.601781
# 2023-07-13    21.606569
# 2023-07-14    21.615865
# 2023-07-17    21.616407
# 2023-07-18    21.619002
# 2023-07-19    21.628186
# 2023-07-20    21.630822
# 2023-07-21    21.632039
# 2023-07-24    21.640275
# 2023-07-25    21.644848
# 2023-07-26    21.645566
# 2023-07-27    21.652376
# 2023-07-28    21.658417
# 2023-07-31    21.659405
# 2023-08-01    21.664675
# 2023-08-02    21.671557
# 2023-08-03    21.673365
# Freq: B, Name: SARIMA(4, 1, 3)x(0, 0, 0, 5) Forecast, dtype: float64
