# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
ticker = "CLP=X"

# %%
df = yf.download(ticker)
df = df["2009-01-01":]
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2009-01-01  629.260010  630.390015  625.950012  628.229980  628.229980       0
# 2009-01-02  628.109985  635.489990  626.520020  629.359985  629.359985       0
# 2009-01-05  627.849976  642.419983  627.849976  634.820007  634.820007       0
# 2009-01-06  635.630005  649.809998  616.780029  618.250000  618.250000       0
# 2009-01-07  618.179993  621.109985  611.909973  618.109985  618.109985       0
# ...                ...         ...         ...         ...         ...     ...
# 2023-05-29  798.049988  800.830017  796.090027  798.049988  798.049988       0
# 2023-05-30  800.650024  808.309998  800.650024  800.650024  800.650024       0
# 2023-05-31  804.349976  809.179993  804.330017  804.349976  804.349976       0
# 2023-06-01  809.630005  810.260010  805.830017  809.630005  809.630005       0
# 2023-06-02  804.059998  804.059998  795.119995  798.570007  798.570007       0
#
# [3757 rows x 6 columns]

# %%
df = df.asfreq('B', method='ffill')

# %%
df.index
# Out:
# DatetimeIndex(['2009-01-01', '2009-01-02', '2009-01-05', '2009-01-06',
#                '2009-01-07', '2009-01-08', '2009-01-09', '2009-01-12',
#                '2009-01-13', '2009-01-14',
#                ...
#                '2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25',
#                '2023-05-26', '2023-05-29', '2023-05-30', '2023-05-31',
#                '2023-06-01', '2023-06-02'],
#               dtype='datetime64[ns]', name='Date', length=3762, freq='B')

# %%
plt.figure(figsize=(12, 8))
plt.plot(df["Adj Close"])
plt.title(f"{ticker} Adjusted Close Price")
plt.xlabel('Year')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df['Adj Close'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic        -1.047713
# p-value                    0.735467
# # lags used                9.000000
# # observations          3752.000000
# critical value (1%)       -3.432094
# critical value (5%)       -2.862311
# critical value (10%)      -2.567180
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
len(df)
# Out:
# 3762

# %%
q_80 = int(len(df) * .8)

# %%
y_train = df['Adj Close'].iloc[:q_80]
y_test = df['Adj Close'].iloc[q_80:]

# %%
y_train.plot(figsize = (12, 8))
y_test.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = auto_arima(y_train, trace = True, seasonal = True, m = 5)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[5] intercept   : AIC=25964.469, Time=3.65 sec
#  ARIMA(0,1,0)(0,0,0)[5] intercept   : AIC=27327.814, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,0)[5] intercept   : AIC=26562.046, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,1)[5] intercept   : AIC=25957.152, Time=0.61 sec
#  ARIMA(0,1,0)(0,0,0)[5]             : AIC=27325.830, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[5] intercept   : AIC=25955.168, Time=0.35 sec
#  ARIMA(0,1,1)(1,0,0)[5] intercept   : AIC=25957.151, Time=0.56 sec
#  ARIMA(0,1,1)(1,0,1)[5] intercept   : AIC=25959.086, Time=1.21 sec
#  ARIMA(1,1,1)(0,0,0)[5] intercept   : AIC=25956.928, Time=0.43 sec
#  ARIMA(0,1,2)(0,0,0)[5] intercept   : AIC=25956.924, Time=0.45 sec
#  ARIMA(1,1,0)(0,0,0)[5] intercept   : AIC=26560.068, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,0)[5] intercept   : AIC=25959.150, Time=0.62 sec
#  ARIMA(0,1,1)(0,0,0)[5]             : AIC=25953.716, Time=0.17 sec
#  ARIMA(0,1,1)(1,0,0)[5]             : AIC=25955.698, Time=0.29 sec
#  ARIMA(0,1,1)(0,0,1)[5]             : AIC=25955.699, Time=0.32 sec
#  ARIMA(0,1,1)(1,0,1)[5]             : AIC=25957.629, Time=0.77 sec
#  ARIMA(1,1,1)(0,0,0)[5]             : AIC=25955.488, Time=0.22 sec
#  ARIMA(0,1,2)(0,0,0)[5]             : AIC=25955.484, Time=0.24 sec
#  ARIMA(1,1,0)(0,0,0)[5]             : AIC=26558.115, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[5]             : AIC=25957.699, Time=0.31 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[5]
# Total fit time: 11.028 seconds

# %% [markdown]
# Potential models are:
# - SARIMA(0,1,1)x(0,0,0,5)
# - SARIMA(0,1,2)x(0,0,0,5)
# - SARIMA(1,1,1)x(0,0,0,5)
# - SARIMA(0,1,1)x(1,0,0,5)

# %%
model_list = {"order": [(0, 1, 1), (0, 1, 2), (1, 1 ,1), (0, 1 ,1)], "seasonal_order": [(0,0,0,5), (0,0,0,5), (0,0,0,5), (1,0,0,5)], "trend": ["n", "n", "n", "n"]}

# %%
from statsmodels.tools.eval_measures import rmse

# %%
metrics = pd.DataFrame(data = {"Order" : [], "Seasonal Order": [], "Trend": [], "AIC": [], "BIC" : [], "RMSE": []})
metric_rows = []
   
start = len(y_train)
end = len(y_train) + len(y_test) -1

for order, seasonal_order, trend in zip(model_list["order"], model_list["seasonal_order"], model_list["trend"]):
    model= SARIMAX(y_train, order = order, seasonal_order = seasonal_order, enforce_invertibility = True, trend = trend).fit()

    y_pred = model.predict(start, end)
    rmse_model = rmse(y_test, y_pred)
    
    metric_rows.append({"Order" : order, "Seasonal Order": seasonal_order, "Trend": trend, "AIC": model.aic, "BIC" : model.bic, "RMSE": rmse_model})
    
metrics = pd.concat([metrics, pd.DataFrame(metric_rows)], ignore_index=True)

# %%
metrics = metrics.sort_values("RMSE")
metrics
# Out:
#        Order Seasonal Order Trend           AIC           BIC       RMSE
# 1  (0, 1, 2)   (0, 0, 0, 5)     n  25955.484224  25973.511316  69.865791
# 2  (1, 1, 1)   (0, 0, 0, 5)     n  25955.488198  25973.515290  69.865863
# 0  (0, 1, 1)   (0, 0, 0, 5)     n  25953.716347  25965.734408  69.892458
# 3  (0, 1, 1)   (1, 0, 0, 5)     n  25955.698469  25973.725561  69.896165

# %% [markdown]
# The best model is SARIMA(0,1,3)x(2,0,2,12)

# %%
selected_model = SARIMAX(y_train, order = metrics["Order"].iloc[0], seasonal_order = metrics["Seasonal Order"].iloc[0], enforce_invertibility = True, trend = metrics["Trend"].iloc[0]).fit()
y_hat_test = selected_model.predict(start, end).rename("Test Predictions")
plt.figure(figsize = (12, 8))
y_test.plot(legend = True)
y_hat_test.plot(legend = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
final_model =  SARIMAX(df["Adj Close"], order = metrics["Order"].iloc[0], seasonal_order = metrics["Seasonal Order"].iloc[0], enforce_invertibility = True, trend = metrics["Trend"].iloc[0]).fit()
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Adj Close   No. Observations:                 3762
# Model:               SARIMAX(0, 1, 2)   Log Likelihood              -16044.768
# Date:                Fri, 02 Jun 2023   AIC                          32095.536
# Time:                        15:45:22   BIC                          32114.234
# Sample:                    01-01-2009   HQIC                         32102.185
#                          - 06-02-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6729      0.002   -385.097      0.000      -0.676      -0.670
# ma.L2         -0.0149      0.003     -5.773      0.000      -0.020      -0.010
# sigma2       297.1141      0.339    876.297      0.000     296.450     297.779
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):         109864972.56
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.76   Skew:                           -22.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                       839.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
forecast_size = 44

# %%
final_order  = metrics["Order"].iloc[0]
final_seasonal_order = metrics["Seasonal Order"].iloc[0]

# %%
y_forecast = final_model.predict(start = len(df), end = len(df) + forecast_size - 1, typ = "levels").rename(f"SARIMA{final_order}x{final_seasonal_order} Forecast")

# %%
plt.figure(figsize = (12, 8))
df["Adj Close"].plot(legend = True)
y_forecast.plot(legend = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize = (12, 8))
df["Adj Close"].iloc[-30:].plot(legend = True)
y_forecast.plot(legend = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
y_forecast
# Out:
# 2023-06-05    802.453899
# 2023-06-06    802.542587
# 2023-06-07    802.542587
# 2023-06-08    802.542587
# 2023-06-09    802.542587
# 2023-06-12    802.542587
# 2023-06-13    802.542587
# 2023-06-14    802.542587
# 2023-06-15    802.542587
# 2023-06-16    802.542587
# 2023-06-19    802.542587
# 2023-06-20    802.542587
# 2023-06-21    802.542587
# 2023-06-22    802.542587
# 2023-06-23    802.542587
# 2023-06-26    802.542587
# 2023-06-27    802.542587
# 2023-06-28    802.542587
# 2023-06-29    802.542587
# 2023-06-30    802.542587
# 2023-07-03    802.542587
# 2023-07-04    802.542587
# 2023-07-05    802.542587
# 2023-07-06    802.542587
# 2023-07-07    802.542587
# 2023-07-10    802.542587
# 2023-07-11    802.542587
# 2023-07-12    802.542587
# 2023-07-13    802.542587
# 2023-07-14    802.542587
# 2023-07-17    802.542587
# 2023-07-18    802.542587
# 2023-07-19    802.542587
# 2023-07-20    802.542587
# 2023-07-21    802.542587
# 2023-07-24    802.542587
# 2023-07-25    802.542587
# 2023-07-26    802.542587
# 2023-07-27    802.542587
# 2023-07-28    802.542587
# 2023-07-31    802.542587
# 2023-08-01    802.542587
# 2023-08-02    802.542587
# 2023-08-03    802.542587
# Freq: B, Name: SARIMA(0, 1, 2)x(0, 0, 0, 5) Forecast, dtype: float64
